# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardo-IA/projeto_dados_covid/blob/main/C%C3%B3pia_de_Analise_Explorat%C3%B3rio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Projeto de Análise de dados bootcamp Dio / Unimed**
# Analise de dados sobre covid nos Estados Brasileiros

# %%
#importando a biblioteca Pandas

import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv')

# %%
#visualizando as 5 primeiras colunas
df.head()
# Out:
#    epi_week        date country  state   city  newDeaths  deaths  newCases  \
# 0         9  2020-02-25  Brazil     SP  TOTAL          0       0         1
# 1         9  2020-02-25  Brazil  TOTAL  TOTAL          0       0         1
# 2         9  2020-02-26  Brazil     SP  TOTAL          0       0         0
# 3         9  2020-02-26  Brazil  TOTAL  TOTAL          0       0         0
# 4         9  2020-02-27  Brazil     SP  TOTAL          0       0         0
#
#    totalCases  deathsMS  ...  tests  tests_per_100k_inhabitants  vaccinated  \
# 0           1         0  ...    NaN                         NaN         NaN
# 1           1         0  ...    NaN                         NaN         NaN
# 2           1         0  ...    NaN                         NaN         NaN
# 3           1         0  ...    NaN                         NaN         NaN
# 4           1         0  ...    NaN                         NaN         NaN
#
#    vaccinated_per_100_inhabitants  vaccinated_second  \
# ...

# %%
#selecionando colunas do dataframe
df = df.loc[:,["date","country","city","state","tests","totalCases","newCases","vaccinated","deaths"]]
df.head()
# Out:
#          date country   city  state  tests  totalCases  newCases  vaccinated  \
# 0  2020-02-25  Brazil  TOTAL     SP    NaN           1         1         NaN
# 1  2020-02-25  Brazil  TOTAL  TOTAL    NaN           1         1         NaN
# 2  2020-02-26  Brazil  TOTAL     SP    NaN           1         0         NaN
# 3  2020-02-26  Brazil  TOTAL  TOTAL    NaN           1         0         NaN
# 4  2020-02-27  Brazil  TOTAL     SP    NaN           1         0         NaN
#
#    deaths
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#Renomeando colunas do dataframe
df = df.rename(columns={"date":"Data","country":"Pais", "city":"Cidade","state":"Estado","tests": "Testes","totalCases":"Total de casos","newCases":"Novos casos","vaccinated":"Vacinados","deaths":"Mortos" })
df.head()
# Out:
#          Data    Pais Cidade Estado  Testes  Total de casos  Novos casos  \
# 0  2020-02-25  Brazil  TOTAL     SP     NaN               1            1
# 1  2020-02-25  Brazil  TOTAL  TOTAL     NaN               1            1
# 2  2020-02-26  Brazil  TOTAL     SP     NaN               1            0
# 3  2020-02-26  Brazil  TOTAL  TOTAL     NaN               1            0
# 4  2020-02-27  Brazil  TOTAL     SP     NaN               1            0
#
#    Vacinados  Mortos
# 0        NaN       0
# 1        NaN       0
# 2        NaN       0
# 3        NaN       0
# 4        NaN       0

# %%
#informações estatistica
df.describe()
# Out:
#                     Testes       Total de casos          Novos casos  \
# count            24,748.00            26,082.00            26,082.00
# mean          3,273,460.98         1,181,462.13             2,657.33
# std           9,802,599.72         3,754,980.66             9,731.18
# min                 854.00                 1.00           -19,581.00
# 25%             355,079.25           121,147.75               133.00
# 50%             870,146.00           328,928.50               549.00
# 75%           2,218,686.00           796,034.00             1,587.00
# max          70,923,215.00        34,654,190.00           285,396.00
#
#                  Vacinados               Mortos
# count            17,351.00            26,082.00
# mean          8,911,228.01            28,876.60
# std          26,275,118.92            89,560.79
# min                   2.00                 0.00
# 25%             698,418.00             2,158.00
# 50%           2,555,998.00             7,355.00
# ...

# %%
#convertendo a notação cientifica
pd.options.display.float_format ='{:20,.2f}'.format
df.head()
# Out:
#          Data    Pais Cidade Estado  Testes  Total de casos  Novos casos  \
# 0  2020-02-25  Brazil  TOTAL     SP     NaN               1            1
# 1  2020-02-25  Brazil  TOTAL  TOTAL     NaN               1            1
# 2  2020-02-26  Brazil  TOTAL     SP     NaN               1            0
# 3  2020-02-26  Brazil  TOTAL  TOTAL     NaN               1            0
# 4  2020-02-27  Brazil  TOTAL     SP     NaN               1            0
#
#    Vacinados  Mortos
# 0        NaN       0
# 1        NaN       0
# 2        NaN       0
# 3        NaN       0
# 4        NaN       0

# %%
#Estados confirmados
df.Estado.unique()
# Out:
# array(['SP', 'TOTAL', 'RJ', 'BA', 'ES', 'DF', 'AL', 'MG', 'RS', 'GO',
#        'PE', 'PR', 'RN', 'SC', 'AM', 'MS', 'SE', 'CE', 'AC', 'PA', 'PB',
#        'TO', 'PI', 'AP', 'MA', 'MT', 'RO', 'RR'], dtype=object)

# %%
#Estados e total de casos

# %%
#total de casos por estados
df.groupby("Estado")["Total de casos"].sum().sort_values(ascending = False)
# Out:
# Estado
# TOTAL    15407447577
# SP        2896285492
# MG        1564890752
# PR        1121079507
# RS        1084815347
# RJ         984115847
# SC         860828214
# BA         847188797
# CE         662976714
# GO         650643110
# ES         489392827
# PE         455572295
# PA         434813573
# DF         382764084
# MT         372455576
# AM         322629493
# PB         312852549
# MS         262619972
# MA         259410584
# RN         255416236
# PI         215983725
# RO         201719743
# SE         186643854
# AL         168053527
# TO         161427469
# AP          93423234
# RR          91430216
# AC          68014840
# Name: Total de casos, dtype: int64

# %%
#Grafico do total de casos nos Estados
df.groupby("Estado")["Total de casos"].sum().sort_values(ascending = True).plot.bar(title ="Total Casos por Estados")
plt.xlabel ("Estado")
plt.ylabel("Total de casos");
plt.grid()
